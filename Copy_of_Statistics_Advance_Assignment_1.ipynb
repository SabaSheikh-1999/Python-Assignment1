# %% [markdown]
# <a href="https://colab.research.google.com/github/SabaSheikh-1999/Python-Assignment1/blob/main/Copy_of_Statistics_Advance_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment - Statistics Advance
# Question-1. What is a random variable in probability theory ?
#
# Answer-1. Random Variable A random variable is a mathematical representation of a variable whose possible values are determined by chance or randomness.
#
# Types of Random Variables
#
# Discrete random variable: Takes on a countable number of distinct values (e.g., number of heads in coin flips).
# Continuous random variable: Takes on any value within a given interval or range (e.g., height, temperature).
# Importance Random variables are fundamental in probability theory and statistics, allowing us to:
#
# Model uncertainty: Represent real-world phenomena with inherent randomness.
# Analyze data: Make inferences and predictions about populations based on sample data.
# Applications
#
# Statistics: Hypothesis testing, confidence intervals, regression analysis.
# Probability theory: Calculating probabilities, expectations, and variances.
# Machine learning: Modeling uncertainty, makin
# Question-2. What are the types of random variables ?
#
# Answer-2. A random variable is a mathematical representation of a variable whose possible values are determined by chance or randomness.
#
# Types of Random Variables
#
# Discrete random variable: Takes on a countable number of distinct values (e.g., number of heads in coin flips).
# Continuous random variable: Takes on any value within a given interval or range (e.g., height, temperature).
# Importance Random variables are fundamental in probability theory and statistics, allowing us to:
#
# Model uncertainty: Represent real-world phenomena with inherent randomness.
# Analyze data: Make inferences and predictions about populations based on sample data.
# Applications
#
# Statistics: Hypothesis testing, confidence intervals, regression analysis.
# Probability theory: Calculating probabilities, expectations, and variances.
# Machine learning: Modeling uncertainty, making predictions.
# Question-3. What is the difference between discrete and continuous distributions ?
#
# Answer-3. Discrete Distributions
#
# Countable values: Take on a finite or countable number of distinct values.
# Examples:
# Number of heads in coin flips
# Number of defects in a product
# Number of customers in a store
# Probability mass function (PMF): Describes the probability of each possible value.
# Continuous Distributions
#
# Uncountable values: Take on any value within a given interval or range.
# Examples:
# Height or weight of individuals
# Temperature or pressure readings
# Time between events
# Probability density function (PDF): Describes the relative likelihood of each value.
# Key Differences
#
# Value range: Discrete distributions have distinct, separate values, while continuous distributions have a continuous range of values.
# Probability calculation: Discrete distributions use PMFs, while continuous distributions use PDFs and integration to calculate probabilities.
# Question-4. What are probability distribution functions (PDF) ?
#
# Answer-4.A Probability Density Function (PDF) describes the relative likelihood of each value in a continuous random variable's distribution.
#
# Key Characteristics
#
# Non-negative: PDF values are always non-negative.
# Integrates to 1: The area under the PDF curve is equal to 1, ensuring the total probability is 1.
# Purpose
#
# Describe distribution shape: PDFs illustrate the shape and characteristics of a distribution.
# Calculate probabilities: Probabilities are calculated by integrating the PDF over a specified range.
# Question-5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF) ?
#
# Answer-5. Cumulative Distribution Function (CDF)
#
# Cumulative probability: Gives the probability that a random variable takes on a value less than or equal to a given value.
# Non-decreasing: CDF values increase or remain constant as the value increases.
# Ranges from 0 to 1: CDF values start at 0 and end at 1.
# Probability Density Function (PDF)
#
# Relative likelihood: Describes the relative likelihood of each value in a continuous distribution.
# Non-negative: PDF values are always non-negative.
# Integrates to 1: The area under the PDF curve is equal to 1.
# Key Differences
#
# Cumulative vs instantaneous: CDF gives cumulative probability, while PDF gives relative likelihood.
# Interpretation: CDF is used to calculate probabilities for ranges of values, while PDF is used to understand the distribution's shape.
# Question-6. What is a discrete uniform distribution ?
#
# Answer-6. Definition A discrete uniform distribution is a probability distribution where each possible outcome has an equal probability of occurring.
#
# Key Characteristics
#
# Equal probabilities: Each outcome has the same probability.
# Finite number of outcomes: The distribution has a finite number of distinct outcomes.
# Examples
#
# Rolling a fair die: Each face (1-6) has an equal probability (1/6).
# Coin toss: Heads and tails have equal probabilities (1/2).
# Question-7. What are the key properties of a Bernoulli distribution ?
#
# Answer-7. A Bernoulli distribution is a discrete probability distribution that models a single trial with two possible outcomes: success (1) or failure (0).
#
# Key Properties
#
# Two possible outcomes: Success (1) or failure (0).
# Probability of success: Denoted by p, where 0 ≤ p ≤ 1.
# Probability of failure: Denoted by q = 1 - p.
# Independent trials: Each trial is independent of others.
# Question-8. What is the binomial distribution, and how is it used in probability ?
#
# ANswer-8. he binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has a constant probability of success.
#
# Key Characteristics
#
# Fixed number of trials: Denoted by n.
# Independent trials: Each trial is independent of others.
# Constant probability of success: Denoted by p, where 0 ≤ p ≤ 1.
# Two possible outcomes: Success or failure.Applications
# Quality control: Modeling the number of defective products in a sample.
# Medical research: Modeling the number of patients responding to treatment.
# Finance: Modeling the number of successful investments.
# Real-World Examples
#
# Coin tossing: Modeling the number of heads in a fixed number of coin tosses.
# Product testing: Modeling the number of products that meet quality standards.
# Question-9. What is the Poisson distribution and where is it applied ?
#
# Answer-9. The Poisson distribution is a discrete probability distribution that models the number of events occurring in a fixed interval of time or space, where these events occur with a known constant average rate
#
# Applications
#
# Modeling rare events: The Poisson distribution is suitable for modeling rare events, such as accidents or errors.
# Queueing theory: Modeling the number of arrivals in a queueing system.
# Telecommunications: Modeling the number of phone calls or messages.
# Insurance: Modeling the number of claims.
# Real-World Examples
#
# Number of customers arriving at a store: Modeling the number of customers arriving within a fixed time interval.
# Number of defects in a manufacturing process: Modeling the number of defects occurring within a fixed production run.
# Question-10. What is a continuous uniform distribution ?
#
# Answer-10. A continuous uniform distribution is a probability distribution where every value within a certain range has an equal likelihood of being selected.
#
# Applications
#
# Modeling uncertainty: Continuous uniform distributions are used to model situations where every outcome within a range is equally likely.
# Simulations: Used in simulations to generate random numbers within a specified range.
# Question-11. What are the characteristics of a normal distribution ?
#
# Answer-11. Characteristics
#
# Bell-shaped curve: Symmetrical and bell-shaped.
# Mean, median, and mode are equal: The mean, median, and mode are all located at the center of the distribution.
# Symmetry: The distribution is symmetrical about the mean.
# Defined by mean and standard deviation: The normal distribution is defined by its mean (μ) and standard deviation (σ).
# Question-12. What is the standard normal distribution, and why is it important ?
#
# Answer-12. The standard normal distribution, also known as the z-distribution, is a normal distribution with a mean of 0 and a standard deviation of 1.
#
# Importance
#
# Standardization: The standard normal distribution allows for standardization of normal distributions, enabling comparison and calculation of probabilities.
# Z-scores: The standard normal distribution is used to calculate z-scores, which measure the number of standard deviations from the mean.
# Statistical analysis: The standard normal distribution is widely used in statistical analysis, hypothesis testing, and confidence intervals.
# Question-13. What is the Central Limit Theorem (CLT), and why is it critical in statistics ?
#
# ANswer-13. The Central Limit Theorem (CLT) states that the distribution of sample means approaches a normal distribution as the sample size increases, regardless of the underlying population distribution.
#
# Importance
#
# Statistical inference: The CLT enables statistical inference, such as hypothesis testing and confidence intervals, even when the population distribution is unknown.
# Approximation: The CLT provides a powerful approximation tool for calculating probabilities and making inferences about population means.
# Wide applicability: The CLT applies to a wide range of statistical problems, making it a fundamental concept in statistics.
# Question-14. How does the Central Limit Theorem relate to the normal distribution ?
#
# Answer-14. The Central Limit Theorem (CLT) states that the distribution of sample means approaches a normal distribution as the sample size increases, regardless of the underlying population distribution.
#
# Key Connections
#
# Normal distribution approximation: The CLT implies that the distribution of sample means can be approximated by a normal distribution, even if the population distribution is not normal.
# Increasing sample size: As the sample size increases, the distribution of sample means becomes closer to a normal distribution.
# Question-15. What is the application of Z statistics in hypothesis testing ?
#
# Answer-15. Z-statistics is a statistical measure used in hypothesis testing to determine how many standard deviations an observation is away from the population mean.
#
# Application
#
# Hypothesis testing: Z-statistics is used to test hypotheses about population means, proportions, or other parameters.
# Comparing sample means: Z-statistics can be used to compare sample means to a known population mean or to compare two sample means.
# Calculation The Z-statistic is calculated using the formula:
#
# Z = (x̄ - μ) / (σ / √n)
#
# where x̄ is the sample mean, μ is the population mean, σ is the population standard deviation, and n is the sample size.
#
# Question-16. How do you calculate a Z-score, and what does it represent ?
#
# Answer-16. Formula The Z-score is calculated using the formula:
#
# Z = (X - μ) / σ
#
# where:
#
# X is the individual data point
# μ is the population mean
# σ is the population standard deviation
# Interpretation
#
# Standardized score: The Z-score represents the number of standard deviations an individual data point is away from the population mean.
# Direction: A positive Z-score indicates the data point is above the mean, while a negative Z-score indicates it's below the mean.
# What Z-Score Represents
#
# Relative position: The Z-score represents the relative position of a data point within a distribution.
# Outlier identification: Z-scores can help identify outliers, which are data points significantly different from the rest.
# Question-17. What are point estimates and interval estimates in statistics ?
#
# Answer-17. Point Estimates
#
# Single value: A point estimate is a single value used to estimate a population parameter.
# Example: Sample mean (x̄) as an estimate of population mean (μ).
# Interval Estimates
#
# Range of values: An interval estimate is a range of values within which a population parameter is likely to lie.
# Example: Confidence interval (CI) for a population mean.
# Question-18. What is the significance of confidence intervals in statistical analysis ?
#
# Answer-18. Significance
#
# Quantifying uncertainty: Confidence intervals (CIs) provide a range of values within which a population parameter is likely to lie, quantifying the uncertainty associated with the estimate.
# Statistical inference: CIs are used in statistical inference to make conclusions about population parameters based on sample data.
# Precision: The width of a CI indicates the precision of the estimate, with narrower intervals indicating more precise estimates.
# Applications
#
# Estimating population parameters: CIs are used to estimate population means, proportions, and other parameters.
# Comparing groups: CIs can be used to compare the means or proportions of different groups.
# Decision-making: CIs are useful in decision-making, as they provide a range of plausible values for a population parameter.
# Question-19. What is the relationship between a Z-score and a confidence interval ?
#
# Answer-19. Relationship
#
# Z-score calculation: Z-scores are used to calculate confidence intervals for population means when the population standard deviation is known.
# Critical Z-value: The critical Z-value is used to determine the margin of error in a confidence interval.
# Confidence Interval Formula The formula for a confidence interval using Z-scores is:
#
# CI = x̄ ± (Z * σ / √n)
#
# where:
#
# x̄ is the sample mean
# Z is the critical Z-value
# σ is the population standard deviation
# n is the sample size
# Importance
#
# Constructing CIs: Z-scores are essential for constructing confidence intervals for population means.
# Determining precision: The width of the CI, which is influenced by the Z-score, indicates the precision of the estimate.
# Question-20. How are Z-scores used to compare different distributions ?
#
# Answer-20. Standardization
#
# Common scale: Z-scores standardize values from different distributions, allowing for comparison on a common scale.
# Mean and standard deviation: Z-scores take into account the mean and standard deviation of each distribution.
# Comparison
#
# Relative position: Z-scores indicate the relative position of a value within its distribution.
# Comparing values: Z-scores enable comparison of values from different distributions.
# Question-21. What are the assumptions for applying the Central Limit Theorem ?
#
# Answer-21. Assumptions
#
# Independence: The random variables must be independent of each other.
# Identical distribution: The random variables should be identically distributed (same distribution, mean, and variance).
# Finite variance: The random variables should have a finite variance.
# Sufficiently large sample size: The sample size should be sufficiently large (typically n ≥ 30).
# Question-22. What is the concept of expected value in a probability distribution ?
#
# Answer-22. The expected value (EV) of a random variable is the long-run average value it would take on when the experiment is repeated many times.
#
# Calculation The expected value is calculated as:
#
# E(X) = ∑xP(x)
#
# where:
#
# x represents the possible values of the random variable
# P(x) represents the probability of each value
# Interpretation
#
# Central tendency: The expected value represents the central tendency of a probability distribution.
# Long-run average: The expected value is the average value one would expect to obtain if the experiment were repeated many times.
# Applications
#
# Decision-making: Expected values are used in decision-making under uncertainty.
# Risk analysis: Expected values help assess risk and potential outcomes.
# Question-23. How does a probability distribution relate to the expected outcome of a random variable ?
#
# Answer-23. Relationship
#
# Describes possible outcomes: A probability distribution describes the possible outcomes of a random variable and their associated probabilities.
# Expected value calculation: The expected value of a random variable is calculated using the probability distribution.
# Expected Outcome
#
# Weighted average: The expected outcome is a weighted average of the possible outcomes, where the weights are the probabilities.
# Long-run average: The expected outcome represents the long-run average value of the random variable.
